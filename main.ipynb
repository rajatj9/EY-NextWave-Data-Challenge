# %%
import pandas as pd

# %%
df = pd.read_csv('data_train.csv')

# %%
df.head(20)
# Out:
#     Unnamed: 0                                 hash  \
# 0            0   0000a8602cf2def930488dee7cdad104_1
# 1            1   0000a8602cf2def930488dee7cdad104_1
# 2            2   0000a8602cf2def930488dee7cdad104_1
# 3            3   0000a8602cf2def930488dee7cdad104_1
# 4            4   0000a8602cf2def930488dee7cdad104_1
# 5            5   0000a8602cf2def930488dee7cdad104_1
# 6            6   0000cf177130469eeac79f67b6bcf3df_9
# 7            7   0000cf177130469eeac79f67b6bcf3df_9
# 8            8   0000cf177130469eeac79f67b6bcf3df_9
# 9            9   0000cf177130469eeac79f67b6bcf3df_9
# 10          10   0001f97b99a80f18f62e2d44e54ef33d_3
# 11          11   0001f97b99a80f18f62e2d44e54ef33d_3
# 12          12  0002124248b0ca510dea42824723ccac_31
# 13          13  0002124248b0ca510dea42824723ccac_31
# 14          14  0002124248b0ca510dea42824723ccac_31
# 15          15  0002124248b0ca510dea42824723ccac_31
# 16          16  0002124248b0ca510dea42824723ccac_31
# ...

# %%
df_convert = pd.to_datetime(df['time_exit'], format='%H:%M:%S').dt.time

# %%
df['time_exit_formatted'] = df_convert

# %%
df['time_entry_formatted'].describe()
# Out:
# count       814262
# unique       56765
# top       15:03:00
# freq           103
# Name: time_entry_formatted, dtype: object

# %%
df[df['hash'] == '0000cf177130469eeac79f67b6bcf3df_9']
# Out:
#    Unnamed: 0                                hash  \
# 6           6  0000cf177130469eeac79f67b6bcf3df_9
# 7           7  0000cf177130469eeac79f67b6bcf3df_9
# 8           8  0000cf177130469eeac79f67b6bcf3df_9
# 9           9  0000cf177130469eeac79f67b6bcf3df_9
#
#                                trajectory_id time_entry time_exit      vmax  \
# 6  traj_0000cf177130469eeac79f67b6bcf3df_9_0   14:29:23  14:29:23  0.000000
# 7  traj_0000cf177130469eeac79f67b6bcf3df_9_1   14:39:49  14:39:49  0.000000
# 8  traj_0000cf177130469eeac79f67b6bcf3df_9_2   14:50:14  14:50:14  0.507809
# 9  traj_0000cf177130469eeac79f67b6bcf3df_9_3   15:00:32  15:29:48  1.149404
#
#        vmin     vmean       x_entry       y_entry        x_exit        y_exit  \
# 6  0.000000  0.000000  3.749450e+06 -1.926506e+07  3.749450e+06 -1.926506e+07
# 7  0.000000  0.000000  3.749090e+06 -1.926726e+07  3.749090e+06 -1.926726e+07
# 8  0.507809  0.507809  3.749042e+06 -1.926632e+07  3.749042e+06 -1.926632e+07
# ...
