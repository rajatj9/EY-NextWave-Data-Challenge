# %%
import pandas as pd

# %%
df = pd.read_csv('data_train.csv')

# %%
df.describe()
# Out:
#           Unnamed: 0           vmax           vmin          vmean  \
# count  814262.000000  256769.000000  256769.000000  270778.000000
# mean   407130.500000       2.680249       2.279469       2.454799
# std    235057.336784       7.591053       7.118452       7.160578
# min         0.000000      -1.000000      -1.000000      -1.000000
# 25%    203565.250000       0.000000      -1.000000       0.000000
# 50%    407130.500000       0.000000       0.000000       0.000000
# 75%    610695.750000       0.500000       0.220000       0.440000
# max    814261.000000     162.000000     162.000000     162.000000
#
#             x_entry       y_entry        x_exit        y_exit
# count  8.142620e+05  8.142620e+05  8.142620e+05  8.142620e+05
# mean   3.760411e+06 -1.922153e+07  3.760426e+06 -1.922181e+07
# std    8.974393e+03  7.632234e+04  8.904451e+03  7.515560e+04
# min    3.741027e+06 -1.938291e+07  3.740998e+06 -1.937688e+07
# ...
